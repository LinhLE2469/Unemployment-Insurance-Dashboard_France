# %%
import pandas as pd
from pathlib import Path

# %%
base = Path("/Users/linhle/LinhLe/Apprentisage/EFREI/S1_2025/Data_visualization/Mano_Part/Project_streamlit")
csv_path = base / "data" / "data_cleaned.csv"

# %%
df = pd.read_csv(csv_path, sep=',', engine='python')
df
# Out:
#                           region departement        mois  allocataires_total  \
# 0           Auvergne-Rhône-Alpes    01 - Ain  2020-01-01             36281.0
# 1           Auvergne-Rhône-Alpes    01 - Ain  2020-02-01             35719.0
# 2           Auvergne-Rhône-Alpes    01 - Ain  2020-03-01             37751.0
# 3           Auvergne-Rhône-Alpes    01 - Ain  2020-04-01             39440.0
# 4           Auvergne-Rhône-Alpes    01 - Ain  2020-05-01             39798.0
# ...                          ...         ...         ...                 ...
# 7339  Provence-Alpes-Côte d'Azur       Total  2024-11-01            334986.0
# 7340  Provence-Alpes-Côte d'Azur       Total  2024-12-01            334458.0
# 7341  Provence-Alpes-Côte d'Azur       Total  2025-01-01            335062.0
# 7342  Provence-Alpes-Côte d'Azur       Total  2025-02-01            330274.0
# 7343  Provence-Alpes-Côte d'Azur       Total  2025-03-01            325311.0
#
# ...

# %%
df.shape
# Out:
# (7344, 20)

# %%
numerical_col_names = df.select_dtypes(include=['number']).columns
numerical_col_names
# Out:
# Index(['allocataires_total', 'ouvertures_droit', 'ouvertures_initiales',
#        'reprises', 'fins_droit', 'allocation_jour', 'duree_moy',
#        'allocataires_indemnises', 'allocataires_aref', 'allocataires_asp',
#        'indemnisation_moy_net', 'indemnisation_moy_trav',
#        'indemnisation_moy_non_trav', 'part_trav_mois',
#        'part_trav_mois_indemnise', 'depense_mensuelle'],
#       dtype='object')

# %%
df_num = df.select_dtypes(include=['int64', 'float64'])
df_num
# Out:
#       allocataires_total  ouvertures_droit  ouvertures_initiales  reprises  \
# 0                36281.0            2134.0                1573.0    1261.0
# 1                35719.0            1694.0                1155.0     977.0
# 2                37751.0            1963.0                1881.0    1705.0
# 3                39440.0            1602.0                1525.0    1170.0
# 4                39798.0            1085.0                 998.0     733.0
# ...                  ...               ...                   ...       ...
# 7339            334986.0           20067.0               14640.0   13010.0
# 7340            334458.0           17797.0               11533.0    9548.0
# 7341            335062.0           19151.0               13957.0   10344.0
# 7342            330274.0           14173.0                9787.0    7288.0
# 7343            325311.0           14984.0               10411.0    8092.0
#
# ...
